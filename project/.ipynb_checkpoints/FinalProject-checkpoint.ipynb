# %% [markdown]
# # Introduction and Background

# %% [markdown]
# ## Research Question
# Are there specific months for movie release dates that generate more revenue in the box office? Is there a correlation between movie budgets and their success in the box office?
#
# ## Background
# This is a question of interest because the film industry may be able to find some different strategies to maximize their revenue, such as the best time to release their new movies or determine how much their budget will correlate to potential revenue. With so many movies always coming out, we wondered if there was a correlation between box office success and release dates in conjunction with how big a movie’s budgets is. In some of our background research we found that the number of user votes on IMDB for a movie corresponds with how well-known the film is, and that critics’ reviews don’t have that much of an influence on the success of a movie.
#
# We always hear about big budget movies because they’re the ones that usually have the ability to advertise the film to the point where everyone sees it. But sometimes movies with relatively small budgets rise to the top of the the box offices. Content has something to do with it, but we want to see how much of an impact the time at which you release a movie has on the success of the film. There have been some blog posts about which genre generally gets released for each month, and there was some indication that the winter months would be when the best movies (Oscar nominated ones) come out.
#
# Our question is important because it presents a visualization for the correlation between box office success and release dates in conjuction with movie budgets. We want to know if there is a strong correlation and if there is a pattern to movie release dates. It is unclear if there are popular months for movie releases or box office success.
#
# References (include links):
# - Movie Budget and Financial Performance Records (https://www.the-numbers.com/movie/budgets/)
# -- Tables that show top 20 movies that compare the movie's budget and revenue (greatest lost and earnings).
# - Analysis of factor affecting the success of the movie (http://rstudio-pubs-static.s3.amazonaws.com/233939_bbeb292c0c20440f97d31b616662c06f.html)
# -- Analysis between different website user voting data and the success of the movie in the box office in conjuction with the movie's budget.
# - Movie Release Calendar Strategy (https://riotstudios.com/blog/movie-release-calendar-strategy/)
# -- Months associated with genre/movie style released.
#
# ## Hypothesis
# We predict that if a movie is released during July or August, then it will generate more revenue in the box office. We also predict that if a movie has a big budget, then it will generate more revenue in the box office.

# %% [markdown]
# # Data Description

# %% [markdown]
# This is a list of ~5000 movies from The Movie Database website. This dataset contains rows of movies with columns that dictate details of the movie. For example, the list contains keyword, revenue, budget, production company, imdb id, language, runtime, release date, and ratings concerning each movie.
#
# - Dataset Name: TMDb 5000 Movie Dataset
# - Link to the dataset: https://www.kaggle.com/tmdb/tmdb-movie-metadata/data
# - Number of observations: 4803
#
# This is a list of ~45000 movies from The Movie Database. This list contains budget, genre, original language, popularity, revenue, imdb id, adulterated, production company, homepage, collection, poster, overview, video, tagline, title, vote count, id, runtime, release date, and vote average (0-10) for each movie.
#
# - Dataset Name: Movies Metadata
# - Link to the dataset: https://www.kaggle.com/rounakbanik/the-movies-dataset/data
# - Number of observations: 45466
#
# We may be merging the datasets and compare if there are any duplicates, if so, we will compare the ‘revenue’, ‘budget’, and ‘release date’ and remove the duplicates. If there are any conflicting comparisons, we will manually change the data to the correct values.

# %% [markdown]
# ## Data Cleaning/Pre-processing

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import patsy
import statsmodels.api as sm
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest

# !pip install easymoney
from easymoney.money import EasyPeasy
# Out:
# Collecting easymoney
#   Downloading easymoney-1.5.0.tar.gz
# Requirement already satisfied: numpy in /Users/lixirui/anaconda3/lib/python3.6/site-packages (from easymoney)
# Requirement already satisfied: pandas in /Users/lixirui/anaconda3/lib/python3.6/site-packages (from easymoney)
# Collecting pycountry (from easymoney)
#   Downloading pycountry-18.2.23.tar.gz (9.7MB)
#     100% |████████████████████████████████| 9.7MB 109kB/s ta 0:00:011
# Requirement already satisfied: requests in /Users/lixirui/anaconda3/lib/python3.6/site-packages (from easymoney)
# Collecting wbdata (from easymoney)
#   Downloading wbdata-0.2.7.tar.gz
# Requirement already satisfied: python-dateutil>=2 in /Users/lixirui/anaconda3/lib/python3.6/site-packages (from pandas->easymoney)
# Requirement already satisfied: pytz>=2011k in /Users/lixirui/anaconda3/lib/python3.6/site-packages (from pandas->easymoney)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/lixirui/anaconda3/lib/python3.6/site-packages (from requests->easymoney)
# Requirement already satisfied: idna<2.7,>=2.5 in /Users/lixirui/anaconda3/lib/python3.6/site-packages (from requests->easymoney)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /Users/lixirui/anaconda3/lib/python3.6/site-packages (from requests->easymoney)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lixirui/anaconda3/lib/python3.6/site-packages (from requests->easymoney)
# Requirement already satisfied: decorator in /Users/lixirui/anaconda3/lib/python3.6/site-packages (from wbdata->easymoney)
# Requirement already satisfied: six>=1.5 in /Users/lixirui/anaconda3/lib/python3.6/site-packages (from python-dateutil>=2->pandas->easymoney)
# Building wheels for collected packages: easymoney, pycountry, wbdata
#   Running setup.py bdist_wheel for easymoney ... done
#   Stored in directory: /Users/lixirui/Library/Caches/pip/wheels/c0/aa/d9/4cc4ce15d7722772b7c21de8bcc2fa1a2345fb4d5cd89a657b
#   Running setup.py bdist_wheel for pycountry ... done
#   Stored in directory: /Users/lixirui/Library/Caches/pip/wheels/8e/41/09/9a91004166f9ed503f568eca67141648be1e263021a3d1a5d7
#   Running setup.py bdist_wheel for wbdata ... done
#   Stored in directory: /Users/lixirui/Library/Caches/pip/wheels/6c/cc/78/79154effbbf225d0f06d9b6a270093fe100dd2dc7bbf74007a
# Successfully built easymoney pycountry wbdata
# Installing collected packages: pycountry, wbdata, easymoney
# Successfully installed easymoney-1.5.0 pycountry-18.2.23 wbdata-0.2.7
# You are using pip version 9.0.1, however version 9.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# Import datafile  tmdb_5000_movies.csv to df1

df1 = pd.read_csv('tmdb_5000_movies.csv')

# %%
#Import datafile movies_metadata.csv to df2
df2 = pd.read_csv('movies_metadata.csv', low_memory=False)

# %%
# drop unrelated columns
df1.drop(['homepage', 'keywords', 'overview', 'runtime', 'tagline'], axis=1, inplace=True)
df2.drop(['adult', 'belongs_to_collection', 'homepage', 'imdb_id', 'overview', 'poster_path', 'runtime', 'video', 'tagline'], axis=1, inplace=True)

# %%
# change str to int and drop all unnemerical elements
pd.to_numeric(df1['revenue'], errors='coerce')
pd.to_numeric(df1['budget'], errors='coerce')
pd.to_numeric(df2['revenue'], errors='coerce')
pd.to_numeric(df2['budget'], errors='coerce')             
df1.dropna(subset = ["revenue","budget"],inplace=True)
df2.dropna(subset = ["revenue","budget"],inplace=True)
df2.budget = df2.budget.astype(np.int64)

# %%
# drop unrepresnrable/abnormal value for revenue and budget 
df1 = df1[df1.revenue >= 1000]
df2 = df2[df2.revenue >= 1000]
df1 = df1[df1.budget >= 1000]
df2 = df2[df2.budget >= 1000]

# %%
# Concat two dataset into one called df
df = pd.concat([df1, df2], ignore_index=True)

# %%
# drop repeated infomation.
df.drop_duplicates('id', inplace=True)

# %%
#split the release date to year month and date 
df['year'] = pd.DatetimeIndex(df['release_date']).year
df['month'] = pd.DatetimeIndex(df['release_date']).month
df['date'] = pd.DatetimeIndex(df['release_date']).day

# %%
#remove the movies that may be too old
df = df[df.year >= 1990]
#df['gender'].value_counts()

# %%
#adjust inflation rate 
ep = EasyPeasy()

# %%
# adjust the inflation of budget, make a new column called adjusted_budget
adjusted_budget = []
for index, row in df.iterrows():
    adjusted_budget.append(ep.normalize(amount=row['budget'], region="US", from_year=row['year'], to_year='latest',base_currency="USD", pretty_print=False))
df['adjusted_budget'] = adjusted_budget
# Out:
# /Users/lixirui/anaconda3/lib/python3.6/site-packages/easymoney/money.py:213: UserWarning:
# Inflation (CPI) data for 2017 in 'United States' could not be obtained from the
# International Monetary Fund database currently cached.
# Falling back to 2016.
#   warn(warn_msg % (year, natural_region_name, str(fall_back_year)))

# %%
# adjust the inflation of revenue, make a new column called adjusted_revenue
adjusted_revenue = []
for index, row in df.iterrows():
    adjusted_revenue.append(ep.normalize(amount=row['revenue'], region="US", from_year=row['year'], to_year='latest',base_currency="USD", pretty_print=False))
df['adjusted_revenue'] = adjusted_budget
# Out:
# /Users/lixirui/anaconda3/lib/python3.6/site-packages/easymoney/money.py:213: UserWarning:
# Inflation (CPI) data for 2017 in 'United States' could not be obtained from the
# International Monetary Fund database currently cached.
# Falling back to 2016.
#   warn(warn_msg % (year, natural_region_name, str(fall_back_year)))

# %%
df
# Out:
#          budget                                             genres      id  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
# 5     258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...     559
# 6     260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...   38757
# 7     280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   99861
# 8     250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     767
# 9     250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  209112
# 10    270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...    1452
# 11    200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...   10764
# 12    200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...      58
# 13    255000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   57201
# 14    225000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49521
# 15    225000000  [{"id": 12, "name": "Adventure"}, {"id": 10751...    2454
# 16    220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...   24428
# 17    380000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...    1865
# 18    225000000  [{"id": 28, "name": "Action"}, {"id": 35, "nam...   41154
# 19    250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  122917
# 20    215000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...    1930
# 21    200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   20662
# 22    250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...   57158
# 23    180000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...    2268
# 24    207000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...     254
# 25    200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...     597
# 26    250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...  271110
# 27    209000000  [{"id": 53, "name": "Thriller"}, {"id": 28, "n...   44833
# 28    150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  135397
# 29    200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   37724
# ...         ...                                                ...     ...
# 8490    2500000  [{'id': 9648, 'name': 'Mystery'}, {'id': 28, '...   29361
# 8491    6000000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  102197
# 8492    5000000  [{'id': 28, 'name': 'Action'}, {'id': 10749, '...   63838
# 8493    5000000  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...  375867
# 8494    3000000                     [{'id': 35, 'name': 'Comedy'}]   52891
# 8495    2500000                                                 []   69976
# 8496    4000000  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...  100791
# 8498  152000000  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...  281338
# 8499   21000000  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...  293768
# 8500  197471676  [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...  339964
# 8501    7000000  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...  272610
# 8502    7400000  [{'id': 10769, 'name': 'Foreign'}, {'id': 53, ...   66526
# 8503    2000000  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...   72663
# 8504   10000000  [{'id': 10752, 'name': 'War'}, {'id': 28, 'nam...  326011
# 8505    5300000  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...    8453
# 8506   30000000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  341013
# 8507  100000000  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...  374720
# 8509    8520000  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...  434119
# 8511  260000000  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...  335988
# 8512    2000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  159447
# 8513    2000000                     [{'id': 35, 'name': 'Comedy'}]   75438
# 8514    3000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...   57701
# 8515    2196531  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...   26147
# 8516   60000000  [{'id': 28, 'name': 'Action'}, {'id': 37, 'nam...  353491
# 8517   50000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...  378236
# 8518   11000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...  395834
# 8519   12000000  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...   24049
# 8520     800000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   62757
# 8521    2000000  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...   63281
# 8522    5000000  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...   63898
#
#      original_language                               original_title  \
# 0                   en                                       Avatar
# 1                   en     Pirates of the Caribbean: At World's End
# 2                   en                                      Spectre
# 3                   en                        The Dark Knight Rises
# 4                   en                                  John Carter
# 5                   en                                 Spider-Man 3
# 6                   en                                      Tangled
# 7                   en                      Avengers: Age of Ultron
# 8                   en       Harry Potter and the Half-Blood Prince
# 9                   en           Batman v Superman: Dawn of Justice
# 10                  en                             Superman Returns
# 11                  en                            Quantum of Solace
# 12                  en   Pirates of the Caribbean: Dead Man's Chest
# 13                  en                              The Lone Ranger
# 14                  en                                 Man of Steel
# 15                  en     The Chronicles of Narnia: Prince Caspian
# 16                  en                                 The Avengers
# 17                  en  Pirates of the Caribbean: On Stranger Tides
# 18                  en                               Men in Black 3
# 19                  en    The Hobbit: The Battle of the Five Armies
# 20                  en                       The Amazing Spider-Man
# 21                  en                                   Robin Hood
# 22                  en          The Hobbit: The Desolation of Smaug
# 23                  en                           The Golden Compass
# 24                  en                                    King Kong
# 25                  en                                      Titanic
# 26                  en                   Captain America: Civil War
# 27                  en                                   Battleship
# 28                  en                               Jurassic World
# 29                  en                                      Skyfall
# ...                ...                                          ...
# 8490                ru           Антикиллер Д.К.: Любовь без памяти
# 8491                ru                                        Шпион
# 8492                ru                                  Mechenosets
# 8493                en                               Paris Can Wait
# 8494                ru                                Gitler kaput!
# 8495                ru                               Glukhar v kino
# 8496                ru                       Tot yeshchyo Karloson!
# 8498                en               War for the Planet of the Apes
# 8499                en                                       Kidnap
# 8500                en  Valerian and the City of a Thousand Planets
# 8501                en                                   Black Rose
# 8502                ta                                     முதல்வன்
# 8503                ru                                      Нирвана
# 8504                ru                                    Батальонъ
# 8505                hi                                        Fanaa
# 8506                en                                Atomic Blonde
# 8507                en                                      Dunkirk
# 8509                ko                                           공조
# 8511                en                Transformers: The Last Knight
# 8512                ru                         С новым годом, мамы!
# 8513                ru                                   Beremennyy
# 8514                ru                                 Na Kryuchke!
# 8515                fi                                     FC Venus
# 8516                en                               The Dark Tower
# 8517                en                              The Emoji Movie
# 8518                en                                   Wind River
# 8519                ta                                       சிவாஜி
# 8520                en                                       Dikari
# 8521                en                                   Про любоff
# 8522                ru                                     Антидурь
#
#       popularity                               production_companies  \
# 0        150.438  [{"name": "Ingenious Film Partners", "id": 289...
# 1        139.083  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2        107.377  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3        112.313  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4         43.927        [{"name": "Walt Disney Pictures", "id": 2}]
# 5          115.7  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 6         48.682  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 7        134.279  [{"name": "Marvel Studios", "id": 420}, {"name...
# 8        98.8856  [{"name": "Warner Bros.", "id": 6194}, {"name"...
# 9         155.79  [{"name": "DC Comics", "id": 429}, {"name": "A...
# 10       57.9256  [{"name": "DC Comics", "id": 429}, {"name": "L...
# 11       107.929          [{"name": "Eon Productions", "id": 7576}]
# 12       145.847  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 13        49.047  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 14        99.398  [{"name": "Legendary Pictures", "id": 923}, {"...
# 15       53.9786  [{"name": "Walt Disney", "id": 5888}, {"name":...
# 16       144.449  [{"name": "Paramount Pictures", "id": 4}, {"na...
# 17       135.414  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 18       52.0352  [{"name": "Amblin Entertainment", "id": 56}, {...
# 19       120.966  [{"name": "WingNut Films", "id": 11}, {"name":...
# 20       89.8663  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 21       37.6683  [{"name": "Imagine Entertainment", "id": 23}, ...
# 22       94.3706  [{"name": "WingNut Films", "id": 11}, {"name":...
# 23       42.9909  [{"name": "New Line Cinema", "id": 12}, {"name...
# 24        61.226  [{"name": "WingNut Films", "id": 11}, {"name":...
# 25       100.026  [{"name": "Paramount Pictures", "id": 4}, {"na...
# 26       198.372  [{"name": "Studio Babelsberg", "id": 264}, {"n...
# 27       64.9284  [{"name": "Universal Pictures", "id": 33}, {"n...
# 28       418.709  [{"name": "Universal Studios", "id": 13}, {"na...
# 29        93.005           [{"name": "Columbia Pictures", "id": 5}]
# ...          ...                                                ...
# 8490    0.928271                                                 []
# 8491    1.822246  [{'name': 'Three T Productions', 'id': 3467}, ...
# 8492    0.414793         [{'name': 'Kinokompaniya CTB', 'id': 886}]
# 8493    8.966129          [{'name': 'American Zoetrope', 'id': 70}]
# 8494    0.878255                [{'name': 'Leopolis', 'id': 18044}]
# 8495    0.209434                                                 []
# 8496    0.712585             [{'name': 'Enjoy Movies', 'id': 9340}]
# 8498  146.161786    [{'name': 'Chernin Entertainment', 'id': 7076}]
# 8499   20.214579  [{'name': 'Ingenious Media', 'id': 290}, {'nam...
# 8500   15.262706               [{'name': 'EuropaCorp', 'id': 6896}]
# 8501    2.482771  [{'name': 'Hollywood Storm', 'id': 79736}, {'n...
# 8502    0.236466              [{'name': 'S Pictures', 'id': 14368}]
# 8503    0.679141                                                 []
# 8504    1.557671  [{'name': 'Art Pictures Studio', 'id': 3451}, ...
# 8505    3.003526           [{'name': 'Yash Raj Films', 'id': 1569}]
# 8506   14.455104  [{'name': 'Denver and Delilah Productions', 'i...
# 8507   30.938854  [{'name': 'Canal+', 'id': 5358}, {'name': 'Stu...
# 8509     1.75859         [{'name': 'CJ Entertainment', 'id': 7036}]
# 8511   39.186819  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 8512    1.456046             [{'name': 'Enjoy Movies', 'id': 9340}]
# 8513    0.397106                                                 []
# 8514    0.445269                  [{'name': 'Profit', 'id': 21163}]
# 8515    0.947509             [{'name': 'Talent House', 'id': 4463}]
# 8516   50.903593  [{'name': 'Imagine Entertainment', 'id': 23}, ...
# 8517   33.694599  [{'name': 'Columbia Pictures', 'id': 5}, {'nam...
# 8518   40.796775  [{'name': 'Thunder Road Pictures', 'id': 3528}...
# 8519    1.323587         [{'name': 'AVM Productions', 'id': 16424}]
# 8520    0.903061                                                 []
# 8521    0.121844                  [{'name': 'Profit', 'id': 21163}]
# 8522    0.039793                                                 []
#
#                                    production_countries release_date  \
# 0     [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 1     [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 2     [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 3     [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 4     [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
# 5     [{"iso_3166_1": "US", "name": "United States o...   2007-05-01
# 6     [{"iso_3166_1": "US", "name": "United States o...   2010-11-24
# 7     [{"iso_3166_1": "US", "name": "United States o...   2015-04-22
# 8     [{"iso_3166_1": "GB", "name": "United Kingdom"...   2009-07-07
# 9     [{"iso_3166_1": "US", "name": "United States o...   2016-03-23
# 10    [{"iso_3166_1": "US", "name": "United States o...   2006-06-28
# 11    [{"iso_3166_1": "GB", "name": "United Kingdom"...   2008-10-30
# 12    [{"iso_3166_1": "JM", "name": "Jamaica"}, {"is...   2006-06-20
# 13    [{"iso_3166_1": "US", "name": "United States o...   2013-07-03
# 14    [{"iso_3166_1": "GB", "name": "United Kingdom"...   2013-06-12
# 15    [{"iso_3166_1": "CZ", "name": "Czech Republic"...   2008-05-15
# 16    [{"iso_3166_1": "US", "name": "United States o...   2012-04-25
# 17    [{"iso_3166_1": "US", "name": "United States o...   2011-05-14
# 18    [{"iso_3166_1": "US", "name": "United States o...   2012-05-23
# 19    [{"iso_3166_1": "NZ", "name": "New Zealand"}, ...   2014-12-10
# 20    [{"iso_3166_1": "US", "name": "United States o...   2012-06-27
# 21    [{"iso_3166_1": "GB", "name": "United Kingdom"...   2010-05-12
# 22    [{"iso_3166_1": "NZ", "name": "New Zealand"}, ...   2013-12-11
# 23    [{"iso_3166_1": "GB", "name": "United Kingdom"...   2007-12-04
# 24    [{"iso_3166_1": "NZ", "name": "New Zealand"}, ...   2005-12-14
# 25    [{"iso_3166_1": "US", "name": "United States o...   1997-11-18
# 26    [{"iso_3166_1": "US", "name": "United States o...   2016-04-27
# 27    [{"iso_3166_1": "US", "name": "United States o...   2012-04-11
# 28    [{"iso_3166_1": "US", "name": "United States o...   2015-06-09
# 29    [{"iso_3166_1": "GB", "name": "United Kingdom"...   2012-10-25
# ...                                                 ...          ...
# 8490           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2009-12-03
# 8491           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2012-04-05
# 8492           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2006-10-12
# 8493  [{'iso_3166_1': 'US', 'name': 'United States o...   2016-09-12
# 8494  [{'iso_3166_1': 'UA', 'name': 'Ukraine'}, {'is...   2008-09-18
# 8495           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2010-05-06
# 8496           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2012-03-15
# 8498  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   2017-07-11
# 8499  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2017-08-04
# 8500           [{'iso_3166_1': 'FR', 'name': 'France'}]   2017-07-20
# 8501           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2014-04-17
# 8502            [{'iso_3166_1': 'IN', 'name': 'India'}]   1999-11-07
# 8503           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2008-07-03
# 8504           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2015-02-20
# 8505            [{'iso_3166_1': 'IN', 'name': 'India'}]   2006-05-26
# 8506  [{'iso_3166_1': 'SE', 'name': 'Sweden'}, {'iso...   2017-07-26
# 8507  [{'iso_3166_1': 'NL', 'name': 'Netherlands'}, ...   2017-07-19
# 8509      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]   2017-01-18
# 8511  [{'iso_3166_1': 'US', 'name': 'United States o...   2017-06-21
# 8512           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2012-12-27
# 8513           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2011-07-21
# 8514           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2011-02-03
# 8515          [{'iso_3166_1': 'FI', 'name': 'Finland'}]   2005-12-30
# 8516  [{'iso_3166_1': 'ZA', 'name': 'South Africa'},...   2017-08-03
# 8517  [{'iso_3166_1': 'US', 'name': 'United States o...   2017-07-28
# 8518  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2017-08-03
# 8519            [{'iso_3166_1': 'IN', 'name': 'India'}]   2007-06-14
# 8520                                                 []   2006-11-23
# 8521           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2010-09-30
# 8522           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2007-09-06
#
#            revenue                                   spoken_languages  \
# 0     2.787965e+09  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1     9.610000e+08           [{"iso_639_1": "en", "name": "English"}]
# 2     8.806746e+08  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# 3     1.084939e+09           [{"iso_639_1": "en", "name": "English"}]
# 4     2.841391e+08           [{"iso_639_1": "en", "name": "English"}]
# 5     8.908716e+08  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 6     5.917949e+08           [{"iso_639_1": "en", "name": "English"}]
# 7     1.405404e+09           [{"iso_639_1": "en", "name": "English"}]
# 8     9.339592e+08           [{"iso_639_1": "en", "name": "English"}]
# 9     8.732602e+08           [{"iso_639_1": "en", "name": "English"}]
# 10    3.910812e+08  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 11    5.860907e+08  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 12    1.065660e+09  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 13    8.928991e+07           [{"iso_639_1": "en", "name": "English"}]
# 14    6.628455e+08           [{"iso_639_1": "en", "name": "English"}]
# 15    4.196514e+08           [{"iso_639_1": "en", "name": "English"}]
# 16    1.519558e+09           [{"iso_639_1": "en", "name": "English"}]
# 17    1.045714e+09  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 18    6.240268e+08           [{"iso_639_1": "en", "name": "English"}]
# 19    9.560198e+08           [{"iso_639_1": "en", "name": "English"}]
# 20    7.522159e+08           [{"iso_639_1": "en", "name": "English"}]
# 21    3.106695e+08  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 22    9.584000e+08           [{"iso_639_1": "en", "name": "English"}]
# 23    3.722349e+08  [{"iso_639_1": "is", "name": "\u00cdslenska"},...
# 24    5.500000e+08           [{"iso_639_1": "en", "name": "English"}]
# 25    1.845034e+09  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 26    1.153304e+09  [{"iso_639_1": "ro", "name": "Rom\u00e2n\u0103...
# 27    3.030255e+08  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 28    1.513529e+09           [{"iso_639_1": "en", "name": "English"}]
# 29    1.108561e+09           [{"iso_639_1": "en", "name": "English"}]
# ...            ...                                                ...
# 8490  2.141028e+06           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 8491  4.588176e+06           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 8492  3.919731e+06           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 8493  6.700000e+06  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 8494  9.713500e+06  [{'iso_639_1': 'pl', 'name': 'Polski'}, {'iso_...
# 8495  1.477030e+06           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 8496  9.938268e+06           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 8498  3.699080e+08           [{'iso_639_1': 'en', 'name': 'English'}]
# 8499  2.452716e+07           [{'iso_639_1': 'en', 'name': 'English'}]
# 8500  9.002429e+07  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...
# 8501  8.554500e+05  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 8502  2.200000e+07             [{'iso_639_1': 'ta', 'name': 'தமிழ்'}]
# 8503  2.731370e+05           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 8504  7.547762e+06           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 8505  2.217591e+07  [{'iso_639_1': 'hi', 'name': 'हिन्दी'}, {'iso_...
# 8506  9.000794e+07  [{'iso_639_1': 'sv', 'name': 'svenska'}, {'iso...
# 8507  5.198769e+08  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 8509  5.610000e+07           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# 8511  6.049421e+08           [{'iso_639_1': 'en', 'name': 'English'}]
# 8512  1.166609e+07           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 8513  8.000000e+06           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 8514  1.957000e+06           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 8515  2.411594e+06             [{'iso_639_1': 'fi', 'name': 'suomi'}]
# 8516  7.100000e+07           [{'iso_639_1': 'en', 'name': 'English'}]
# 8517  6.691394e+07           [{'iso_639_1': 'en', 'name': 'English'}]
# 8518  1.847702e+08           [{'iso_639_1': 'en', 'name': 'English'}]
# 8519  1.900000e+07  [{'iso_639_1': 'ta', 'name': 'தமிழ்'}, {'iso_6...
# 8520  1.328612e+06           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 8521  1.268793e+06           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 8522  1.413000e+06           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
#
#         status                                        title  vote_average  \
# 0     Released                                       Avatar           7.2
# 1     Released     Pirates of the Caribbean: At World's End           6.9
# 2     Released                                      Spectre           6.3
# 3     Released                        The Dark Knight Rises           7.6
# 4     Released                                  John Carter           6.1
# 5     Released                                 Spider-Man 3           5.9
# 6     Released                                      Tangled           7.4
# 7     Released                      Avengers: Age of Ultron           7.3
# 8     Released       Harry Potter and the Half-Blood Prince           7.4
# 9     Released           Batman v Superman: Dawn of Justice           5.7
# 10    Released                             Superman Returns           5.4
# 11    Released                            Quantum of Solace           6.1
# 12    Released   Pirates of the Caribbean: Dead Man's Chest           7.0
# 13    Released                              The Lone Ranger           5.9
# 14    Released                                 Man of Steel           6.5
# 15    Released     The Chronicles of Narnia: Prince Caspian           6.3
# 16    Released                                 The Avengers           7.4
# 17    Released  Pirates of the Caribbean: On Stranger Tides           6.4
# 18    Released                               Men in Black 3           6.2
# 19    Released    The Hobbit: The Battle of the Five Armies           7.1
# 20    Released                       The Amazing Spider-Man           6.5
# 21    Released                                   Robin Hood           6.2
# 22    Released          The Hobbit: The Desolation of Smaug           7.6
# 23    Released                           The Golden Compass           5.8
# 24    Released                                    King Kong           6.6
# 25    Released                                      Titanic           7.5
# 26    Released                   Captain America: Civil War           7.1
# 27    Released                                   Battleship           5.5
# 28    Released                               Jurassic World           6.5
# 29    Released                                      Skyfall           6.9
# ...        ...                                          ...           ...
# 8490  Released                               Antikiller D.K           4.6
# 8491  Released                                      The Spy           4.6
# 8492  Released                                  Mechenosets           5.6
# 8493  Released                               Paris Can Wait           6.4
# 8494  Released                              Hitler's Kaput!           3.6
# 8495  Released                               Glukhar v kino           5.9
# 8496  Released                         That still Karloson!           3.5
# 8498  Released               War for the Planet of the Apes           6.7
# 8499  Released                                       Kidnap           6.0
# 8500  Released  Valerian and the City of a Thousand Planets           6.7
# 8501  Released                                   Black Rose           2.0
# 8502  Released                                    Mudhalvan           6.3
# 8503  Released                                      Nirvana           4.7
# 8504  Released                                The Battalion           5.9
# 8505  Released                                        Fanaa           6.7
# 8506  Released                                Atomic Blonde           6.1
# 8507  Released                                      Dunkirk           7.5
# 8509  Released                      Confidential Assignment           6.2
# 8511  Released                Transformers: The Last Knight           6.2
# 8512  Released                     Mommies, Happy New Year!           5.3
# 8513  Released                                     Pregnant           3.1
# 8514  Released                                 On the Hook!           4.7
# 8515  Released                                     FC Venus           5.6
# 8516  Released                               The Dark Tower           5.7
# 8517  Released                              The Emoji Movie           5.8
# 8518  Released                                   Wind River           7.4
# 8519  Released                             Sivaji: The Boss           6.9
# 8520  Released                                      Savages           5.8
# 8521  Released                                  Pro Lyuboff           4.0
# 8522  Released                                      Antidur           1.0
#
#       vote_count  year  month  date  adjusted_budget  adjusted_revenue
# 0        11800.0  2009     12    10     2.651370e+08      2.651370e+08
# 1         4500.0  2007      5    19     3.472620e+08      3.472620e+08
# 2         4466.0  2015     10    26     2.480909e+08      2.480909e+08
# 3         9106.0  2012      7    16     2.613388e+08      2.613388e+08
# 4         2124.0  2012      3     7     2.717923e+08      2.717923e+08
# 5         3576.0  2007      5     1     2.986454e+08      2.986454e+08
# 6         3330.0  2010     11    24     2.861742e+08      2.861742e+08
# 7         6767.0  2015      4    22     2.835324e+08      2.835324e+08
# 8         5293.0  2009      7     7     2.796804e+08      2.796804e+08
# 9         7004.0  2016      3    23     2.500000e+08      2.500000e+08
# 10        1400.0  2006      6    28     3.214515e+08      3.214515e+08
# 11        2965.0  2008     10    30     2.229488e+08      2.229488e+08
# 12        5246.0  2006      6    20     2.381122e+08      2.381122e+08
# 13        2311.0  2013      7     3     2.627172e+08      2.627172e+08
# 14        6359.0  2013      6    12     2.318093e+08      2.318093e+08
# 15        1630.0  2008      5    15     2.508174e+08      2.508174e+08
# 16       11776.0  2012      4    25     2.299781e+08      2.299781e+08
# 17        4948.0  2011      5    14     4.054551e+08      4.054551e+08
# 18        4160.0  2012      5    23     2.352049e+08      2.352049e+08
# 19        4760.0  2014     12    10     2.534543e+08      2.534543e+08
# 20        6586.0  2012      6    27     2.247513e+08      2.247513e+08
# 21        1398.0  2010      5    12     2.201340e+08      2.201340e+08
# 22        4524.0  2013     12    11     2.575659e+08      2.575659e+08
# 23        1303.0  2007     12     4     2.083572e+08      2.083572e+08
# 24        2337.0  2005     12    14     2.543963e+08      2.543963e+08
# 25        7562.0  1997     11    18     2.990433e+08      2.990433e+08
# 26        7241.0  2016      4    27     2.500000e+08      2.500000e+08
# 27        2114.0  2012      4    11     2.184792e+08      2.184792e+08
# 28        8662.0  2015      6     9     1.518924e+08      1.518924e+08
# 29        7604.0  2012     10    25     2.090710e+08      2.090710e+08
# ...          ...   ...    ...   ...              ...               ...
# 8490         5.0  2009     12     3     2.796804e+06      2.796804e+06
# 8491        10.0  2012      4     5     6.272130e+06      6.272130e+06
# 8492         7.0  2006     10    12     5.952805e+06      5.952805e+06
# 8493        25.0  2016      9    12     5.000000e+06      5.000000e+06
# 8494         7.0  2008      9    18     3.344232e+06      3.344232e+06
# 8495         4.0  2010      5     6     2.751675e+06      2.751675e+06
# 8496         6.0  2012      3    15     4.181420e+06      4.181420e+06
# 8498      1675.0  2017      7    11     1.520000e+08      1.520000e+08
# 8499       244.0  2017      8     4     2.100000e+07      2.100000e+07
# 8500       905.0  2017      7    20     1.974717e+08      1.974717e+08
# 8501         6.0  2014      4    17     7.096719e+06      7.096719e+06
# 8502         6.0  1999     11     7     1.066218e+07      1.066218e+07
# 8503         5.0  2008      7     3     2.229488e+06      2.229488e+06
# 8504         6.0  2015      2    20     1.012616e+07      1.012616e+07
# 8505        53.0  2006      5    26     6.309973e+06      6.309973e+06
# 8506       748.0  2017      7    26     3.000000e+07      3.000000e+07
# 8507      2712.0  2017      7    19     1.000000e+08      1.000000e+08
# 8509         5.0  2017      1    18     8.520000e+06      8.520000e+06
# 8511      1440.0  2017      6    21     2.600000e+08      2.600000e+08
# 8512         9.0  2012     12    27     2.090710e+06      2.090710e+06
# 8513         7.0  2011      7    21     2.133974e+06      2.133974e+06
# 8514         3.0  2011      2     3     3.200961e+06      3.200961e+06
# 8515        10.0  2005     12    30     2.699466e+06      2.699466e+06
# 8516       688.0  2017      8     3     6.000000e+07      6.000000e+07
# 8517       327.0  2017      7    28     5.000000e+07      5.000000e+07
# 8518       181.0  2017      8     3     1.100000e+07      1.100000e+07
# 8519        25.0  2007      6    14     1.389048e+07      1.389048e+07
# 8520         6.0  2006     11    23     9.524488e+05      9.524488e+05
# 8521         3.0  2010      9    30     2.201340e+06      2.201340e+06
# 8522         1.0  2007      9     6     5.787701e+06      5.787701e+06
#
# [7108 rows x 20 columns]
